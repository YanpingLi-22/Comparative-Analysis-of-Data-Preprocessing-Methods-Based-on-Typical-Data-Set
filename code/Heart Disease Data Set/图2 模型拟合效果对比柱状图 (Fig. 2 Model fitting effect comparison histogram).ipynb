# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
mpl.rcParams['font.sans-serif']=['SimHei']
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
mpl.rcParams['font.sans-serif']=['SimHei']
from pylab import mpl  

mpl.rcParams['font.sans-serif'] = ['SimHei'] 
def read():
    name_list = ['Accuracy                 ','Precision                 ','Recall                   ','F-score                    ','TPR                  ','FPR                  ','AUC                  ']
    LR=[0.9341,0.9245,0.9608,0.9423,0.9608,0.1000,0.9475]
    DT=[0.7802,0.8780,0.7059,0.7826,0.7059,0.1250,0.8270]
    RF=[0.8791,0.8704,0.9216,0.8952,0.9216,0.1750,0.9392]
    SVM=[0.8901,0.8868,0.9216,0.9038,0.9216,0.1500,0.9485]
    NB = [0.9011,0.9200,0.9020,0.9109,0.9020,0.1000,0.9500]
    KNN = [0.9011,0.9038,0.9216,0.9126,0.9216,0.1250,0.9593]
    NN = [0.9011,0.9375,0.8824,0.9091,0.8824,0.0750,0.9037] 
    location=np.arange(len(name_list))
    width=0.1
    plt.figure(figsize=(16,4))
    plt.bar(location, LR,tick_label = name_list,width = width,label="Logistic Regression",alpha=0.8,color="w",edgecolor="k",align='edge')
    plt.bar(location+width, DT,tick_label = name_list,width = width,label="Desicion Tree",alpha=0.8,color="w",edgecolor="k",hatch='O',align='edge')
    plt.bar(location+width*2, RF,tick_label = name_list,width = width,label="Random Forest",alpha=0.8,color="w",edgecolor="k",hatch='+',align='edge')
    plt.bar(location+width*3, SVM,tick_label = name_list,width = width,label="SVM",alpha=0.8,color="w",edgecolor="k",hatch='x',align='edge')
    plt.bar(location+width*4, NB,tick_label = name_list,width = width,label="Naïve Bayes",alpha=0.8,color="w",edgecolor="k",hatch='\\',align='edge')
    plt.bar(location+width*5, KNN,tick_label = name_list,width = width,label="KNN",alpha=0.8,color="w",edgecolor="k",hatch='*',align='edge')
    plt.bar(location+width*6, NN,tick_label = name_list,width = width,label="Neural Network",alpha=0.8,color="w",edgecolor="k",hatch='o',align='edge')
    
    #默认字体为宋体
    mpl.rcParams['font.family'] = 'sans-serif'
    mpl.rcParams['font.sans-serif'] = ['NSimSun']
    #plt.plot(x,b,linewidth=1,label = '观测站A')
    mpl.rcParams['font.sans-serif']=['SimHei']
    plt.ylabel('指标值（无单位）',size = 12)
    plt.xlabel('指标名称',size = 12)

    #df.plot(kind = 'bar',figsize = (15,5),rot=0,fontsize = 12,width=0.8,color = ["#8AC6D1","#BBDED6","#FFB6B9","#C4F2C8","#FBD1B7","#FEE9b2","#E1C2DB"],hatch=['-', '+', 'x', '\\', '*', 'o', 'O'])
    plt.yticks(fontproperties = 'Times New Roman', size = 12,weight = 'bold')
    plt.xticks(fontproperties = 'Times New Roman', size = 12,weight = 'bold')
    plt.legend(fontsize=12)
    plt.legend(bbox_to_anchor=(0.5, -0.2),loc=8,ncol=10) # , borderaxespad=0
    plt.legend(loc=2, bbox_to_anchor=(1.05,1.0),borderaxespad = 0.)
    #设置图例并且设置图例的字体及大小
    font1 = {'family' : 'Times New Roman',
    'weight' : 'bold',
    'size'   : 10,
    }
    legend = plt.legend(
        prop=font1,bbox_to_anchor=(1.05,1.0),borderaxespad = 0.)
    #plt.grid()
    plt.savefig('图片.png', dpi=500,bbox_inches = 'tight')
    plt.show()

if __name__ == '__main__':
    read()
